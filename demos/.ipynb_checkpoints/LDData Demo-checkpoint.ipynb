# %% [markdown]
# # Demo notebook for LDData repository

# %%
import qmcpy as qp

# %% [markdown]
# ## Lattices
# [qmcpy documentation for lattices](https://qmcpy.readthedocs.io/en/latest/algorithms.html#module-qmcpy.discrete_distribution.lattice.lattice)

# %%
lattice = qp.Lattice(  #set up a lattice
    dimension = 5,
    generating_vector = "LDData/main/lattice/mps.exew_base2_m20_a3_HKKN.txt",
    randomize = False # set to True to apply random shift 
)
x = lattice(0,8) # points from index 0 (inclusive) to 8 (exclusive)
print(x) 
qp.plot_proj(sampler = lattice, n = [16, 64, 256], d_vertical = [2,3,4,5], d_horizontal = [1,2], figfac = 10, where_title = 0.5,
             fig_title = "Lattice with generator mps.exew_base2_m20_a3_HKKN.txt");
# Out:
# [[0.    0.    0.    0.    0.   ]
#  [0.5   0.5   0.5   0.5   0.5  ]
#  [0.25  0.25  0.25  0.75  0.75 ]
#  [0.75  0.75  0.75  0.25  0.25 ]
#  [0.125 0.625 0.625 0.875 0.375]
#  [0.625 0.125 0.125 0.375 0.875]
#  [0.375 0.875 0.875 0.625 0.125]
#  [0.875 0.375 0.375 0.125 0.625]]
# /Users/fredhickernell/SoftwareRepositories/QMCSoftware/qmcpy/discrete_distribution/lattice/lattice.py:253
# 	ParameterWarning: Non-randomized lattice sequence includes the origin

# %% [markdown]
# ## Digital Nets
# [qmcpy documentation for digital nets](https://qmcpy.readthedocs.io/en/latest/algorithms.html#module-qmcpy.discrete_distribution.digital_net_b2.digital_net_b2)

# %%
dnb2 = qp.DigitalNetB2(
    dimension = 3,
    generating_matrices = "LDData/main/dnet/mps.sobol_Cs.txt",
    randomize = False # set to True to apply left linear matrix scrambling with digital shift 
    # other randomization options are also supported
)
x = dnb2(0,8) # points from index 0 (inclusive) to 8 (exclusive)
print(x)
qp.plot_proj(sampler = dnb2, n = [16, 64, 256], d_vertical = [2,3], d_horizontal = [1,2], 
             fig_title = "Digital net with generator mps.exew_base2_m20_a3_HKKN.txt");
# Out:
# [[0.    0.    0.   ]
#  [0.5   0.5   0.5  ]
#  [0.25  0.75  0.75 ]
#  [0.75  0.25  0.25 ]
#  [0.125 0.625 0.375]
#  [0.625 0.125 0.875]
#  [0.375 0.375 0.625]
#  [0.875 0.875 0.125]]
# /Users/fredhickernell/SoftwareRepositories/QMCSoftware/qmcpy/discrete_distribution/digital_net_b2/digital_net_b2.py:385
# 	ParameterWarning: Non-randomized DigitalNetB2 sequence includes the origin
# /Users/fredhickernell/SoftwareRepositories/QMCSoftware/qmcpy/discrete_distribution/digital_net_b2/digital_net_b2.py:385
# 	ParameterWarning: Non-randomized DigitalNetB2 sequence includes the origin

# %%
lattice = qp.Lattice(
    dimension = 3,
    generating_vector = "LDData/main/lattice/mps.exew_base2_m20_a3_HKKN.txt",
    randomize = False # set to True to apply random shift 
)
x = lattice(0,8) # points from index 0 (inclusive) to 8 (exclusive)
print(x) 

# digital net in base 2 
# https://qmcpy.readthedocs.io/en/latest/algorithms.html#module-qmcpy.discrete_distribution.digital_net_b2.digital_net_b2
dnb2 = qp.DigitalNetB2(
    dimension = 3,
    generating_matrices = "LDData/main/dnet/mps.sobol_Cs.txt",
    randomize = False # set to True to apply left linear matrix scrambling with digital shift 
    # other randomization options are also supported
)
x = dnb2(0,8) # points from index 0 (inclusive) to 8 (exclusive)
print(x)
# Out:
# /Users/fredhickernell/SoftwareRepositories/QMCSoftware/qmcpy/discrete_distribution/lattice/lattice.py:253
# 	ParameterWarning: Non-randomized lattice sequence includes the origin
# [[0.    0.    0.   ]
#  [0.5   0.5   0.5  ]
#  [0.25  0.25  0.25 ]
#  [0.75  0.75  0.75 ]
#  [0.125 0.625 0.625]
#  [0.625 0.125 0.125]
#  [0.375 0.875 0.875]
#  [0.875 0.375 0.375]]
# [[0.    0.    0.   ]
#  [0.5   0.5   0.5  ]
#  [0.25  0.75  0.75 ]
#  [0.75  0.25  0.25 ]
#  [0.125 0.625 0.375]
#  [0.625 0.125 0.875]
#  [0.375 0.375 0.625]
#  [0.875 0.875 0.125]]
# /Users/fredhickernell/SoftwareRepositories/QMCSoftware/qmcpy/discrete_distribution/digital_net_b2/digital_net_b2.py:385
# 	ParameterWarning: Non-randomized DigitalNetB2 sequence includes the origin
